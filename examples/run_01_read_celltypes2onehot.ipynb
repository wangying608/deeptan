# %% [markdown]
# ### celltypes to one-hot encoding

# %%
from deeptan.utils.data import read_h5ad_celltypes2onehot

# %% [markdown]
# #### Start

# %%
read_h5ad_celltypes2onehot("/Path/to/your_raw_data.h5ad", celltype_key="CellType")
