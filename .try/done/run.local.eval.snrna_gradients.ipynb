# %% [markdown]
# # Evalvaluate Predictions

# %%
# %load_ext autoreload
# %autoreload 2
import os
import polars as pl
import numpy as np
from deeptan.stat.metrics import MetricsDictMaker
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Computing metrics

# %%
path_home_deeptan = "/mnt/hdd2/homext/wuch/xn2p"
path_predictions = os.path.join(path_home_deeptan, "run", "predict", "deeptan")
path_raw_df = os.path.join(path_home_deeptan, "data", "raw_df")

# %%
omics = "sc_rna"
path_true = os.path.join(path_raw_df, "scRNA", "GSE226097_Annotated_split_strata")
path_orig_h5ad = os.path.join(path_true, "origin.h5ad")

# %%
_dirs = os.listdir(path_predictions)
_dirs = [d for d in _dirs if d.startswith(omics)]

summary_recon = []
summary_label = []
summary_clust = []
for dataset in _dirs:
    if dataset.find("+") != -1:
        _n_feat = int(dataset.split("+")[1].split("_")[1])
        _trn_data = dataset.split("+")[0]
    else:
        _n_feat = 2000
        _trn_data = dataset

    if _trn_data.endswith("quarter"):
        _trn_grad = 2
    elif _trn_data.endswith("half"):
        _trn_grad = 4
    elif _trn_data.endswith("eighth"):
        _trn_grad = 1
    else:
        _trn_grad = 8
    
    print(f"\nProcessing {dataset} with {_n_feat} input features and the {_trn_grad} train size gradient.")

    metricsmaker = MetricsDictMaker(os.path.join(path_predictions, dataset), path_true, True, path_orig_h5ad, "multitask", "tst")
    metricsmaker.run()
    # try:
    #     metricsmaker = MetricsDictMaker(os.path.join(path_predictions, dataset), path_true, True, path_orig_h5ad, "multitask", "tst")
    #     metricsmaker.run()
    # except Exception as e:
    #     print(f"Error processing {dataset}: {e}")
    #     continue
    _summary_recon = metricsmaker.metrics_dict["summary_recon"]
    _summary_label = metricsmaker.metrics_dict["summary_label"]
    _summary_clust = metricsmaker.metrics_dict["summary_clustering"]
    _nrow_recon = len(_summary_recon)
    _nrow_label = len(_summary_label)
    _nrow_clust = len(_summary_clust)
    summary_recon.append(pl.DataFrame({"n_feat": [_n_feat] * _nrow_recon, "trn_grad": [_trn_grad] * _nrow_recon, "trn_data": [_trn_data] * _nrow_recon}).hstack(_summary_recon))
    summary_label.append(pl.DataFrame({"n_feat": [_n_feat] * _nrow_label, "trn_grad": [_trn_grad] * _nrow_label, "trn_data": [_trn_data] * _nrow_label}).hstack(_summary_label))
    summary_clust.append(pl.DataFrame({"n_feat": [_n_feat] * _nrow_clust, "trn_grad": [_trn_grad] * _nrow_clust, "trn_data": [_trn_data] * _nrow_clust}).hstack(_summary_clust))

summary_recon = pl.concat(summary_recon)
summary_label = pl.concat(summary_label)
summary_clust = pl.concat(summary_clust)
summary_recon.write_csv(f"result.{omics}.summary_recon.csv")
summary_label.write_csv(f"result.{omics}.summary_label.csv")
summary_clust.write_csv(f"result.{omics}.summary_clustering.csv")
# Out:
# Processing sc_rna_annotated_minmi0.1_top2000+top_800 with 800 input features and the 8 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_eighth+top_1200 with 1200 input features and the 1 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_quarter+top_400 with 400 input features and the 2 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000 with 2000 input features and the 8 train size gradient.
# Skipping task focus_label as it does not match the specified task multitask.
# Skipping task multitask_noguide as it does not match the specified task multitask.
# Skipping task focus_label_on_focus_recon as it does not match the specified task multitask.
# Skipping split val as it does not match the specified split tst.
# Skipping task focus_label as it does not match the specified task multitask.
# Skipping task multitask_noguide as it does not match the specified task multitask.
# Skipping task focus_recon as it does not match the specified task multitask.
# Skipping split trn as it does not match the specified split tst.
# Skipping task multitask_noguide as it does not match the specified task multitask.
# Skipping task focus_recon as it does not match the specified task multitask.
# Skipping task focus_recon as it does not match the specified task multitask.
# Skipping task multitask_noguide as it does not match the specified task multitask.
# Skipping task focus_label as it does not match the specified task multitask.
# Skipping task multitask_noguide as it does not match the specified task multitask.
# Skipping task focus_label_on_focus_recon as it does not match the specified task multitask.
# Skipping task focus_label as it does not match the specified task multitask.
# Skipping task focus_recon as it does not match the specified task multitask.
# Skipping task focus_label_on_focus_recon as it does not match the specified task multitask.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000+top_1200 with 1200 input features and the 8 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_quarter+top_1200 with 1200 input features and the 2 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_eighth+top_400 with 400 input features and the 1 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000+top_1600 with 1600 input features and the 8 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_quarter+top_800 with 800 input features and the 2 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_half+top_800 with 800 input features and the 4 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_eighth+top_1600 with 1600 input features and the 1 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_half+top_1600 with 1600 input features and the 4 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_half with 2000 input features and the 4 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_eighth with 2000 input features and the 1 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_quarter with 2000 input features and the 2 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000+top_400 with 400 input features and the 8 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_half+top_400 with 400 input features and the 4 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_quarter+top_1600 with 1600 input features and the 2 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_half+top_1200 with 1200 input features and the 4 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Processing sc_rna_annotated_minmi0.1_top2000_eighth+top_800 with 800 input features and the 1 train size gradient.
#
# Computing metrics for recon...
# Computing metrics for label...
# Calculating cluster metrics...
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/wuch/miniforge3/envs/sc/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %% [markdown]
# ### Save to CSV

# %%
# metricsmaker.metrics_dict["summary_recon"].write_csv(f"result.{dataset}.summary_recon.csv")
# metricsmaker.metrics_dict["summary_label"].write_csv(f"result.{dataset}.summary_label.csv")
# metricsmaker.metrics_dict["summary_clustering"].write_csv(f"result.{dataset}.summary_clustering.csv")

# %% [markdown]
# ## Plot

# %%
from deeptan.stat.plots import kde_grid_plot, kde_grid_plot_data, metrics_plot, metrics_plot_data, pacmap_plot, pacmap_plot_data

# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.figure_dpi = 300

# %% [markdown]
# ### Plot recon distribution

# %%
_dim = "sample_metrics"
# dim = "feature_metrics"

_metrics = ["mse", "mae", "jsd", "pcc"]
_metrics_text = ["MSE", "MAE", "JSD", "PCC"]

x_lab = "multitask"
x_lab_text = "Multitask"

y_labs = ["multitask_noguide", "focus_recon", "focus_label_on_focus_recon", "focus_label"]
y_labs_text = ["Multitask (no SGG)", "Focus on reconstruction", "Fine-tuned on reconstruction", "Focus on labelling"]
# y_labs = ["focus_recon", "focus_label_on_focus_recon", "focus_label"]
# y_labs_text = ["Focus on reconstruction", "Fine-tuned on reconstruction", "Focus on labelling"]

_tasks = [x_lab] + y_labs

# %%
_tmp_dataset = metricsmaker_snrna
_split = "tst"
fig_name = f"fig.c2.snrna.{_split}.recon_sgg.dist"
# fig_name = f"fig.c2.snrna.{_split}.recon.dist"

data4kde = kde_grid_plot_data(_tmp_dataset, 42, _metrics, _tasks, _dim)
_fig = kde_grid_plot(data4kde, x_lab, y_labs, _metrics, _metrics_text, x_lab_text, y_labs_text, _dim, fig_name, ".fig/", _split)

# %% [markdown]
# ### Plot all metrics

# %%
_tmp_dataset = metricsmaker_snrna
_split = "tst"
fig_name = f"fig.c2.snrna.{_split}.metrics_sgg"
# fig_name = f"fig.c2.snrna.{_split}.metrics"

_df_plot_allmetrics = metrics_plot_data(_tmp_dataset, _split)
_df_plot_allmetrics = _df_plot_allmetrics.filter(~pl.col("Metric").is_in(["Spearman", "AMI (Leiden)", "NMI (Leiden)", "ARI (Leiden)"]))
# _df_plot_allmetrics = _df_plot_allmetrics.filter(pl.col("Task") != "Multitask (no SGG)").filter(pl.col("Metric") != "Spearman")
_fig = metrics_plot(_df_plot_allmetrics, fig_name, ".fig/")

# %% [markdown]
# ### Plot PaCMAP

# %%
_tmp_dataset = metricsmaker_snrna
_seed = 42
_split = "tst"
fig_name = f"fig.c2.snrna.{_split}.cell_emb_sgg"
# fig_name = f"fig.c2.snrna.{_split}.cell_emb"

x_lab = "multitask"
x_lab_text = "Multitask"

y_labs = ["multitask_noguide", "focus_recon", "focus_label_on_focus_recon", "focus_label"]
y_labs_text = ["Multitask (no SGG)", "Focus on reconstruction", "Fine-tuned on reconstruction", "Focus on labelling"]
# y_labs = ["focus_recon", "focus_label_on_focus_recon", "focus_label"]
# y_labs_text = ["Focus on reconstruction", "Fine-tuned on reconstruction", "Focus on labelling"]

_tasks = [x_lab] + y_labs
_tasks_text = [x_lab_text] + y_labs_text

# %%
cell_embs_pacmap, y_true_text, ys_pred_text = pacmap_plot_data(_tmp_dataset, _tasks, _split, _seed)

# %% [markdown]
# #### Now we can plot

# %%
_fig = pacmap_plot(cell_embs_pacmap, _tasks_text, y_true_text, ys_pred_text, fig_name, ".fig/")

# %% [markdown]
# ### Plot feature embeddings

# %%
_tmp_dataset = metricsmaker_snrna
_seed = 42
_split = "tst"
fig_name = f"fig.c2.snrna.{_split}.feature_emb"

# %%
# Get feature names
_feat_names = _tmp_dataset.metrics_dict["true"][f"seed_{_seed}_{_split}"]["feature_names"]
_modality = ["Peak" for i in _feat_names if ":" in i else "RNA"]

# %%
x_lab = "multitask"
x_lab_text = "Multitask"

y_labs = ["multitask_noguide", "focus_recon", "focus_label_on_focus_recon", "focus_label"]
y_labs_text = ["Multitask (no SGG)", "Focus on reconstruction", "Fine-tuned on reconstruction", "Focus on labelling"]
# y_labs = ["focus_recon", "focus_label_on_focus_recon", "focus_label"]
# y_labs_text = ["Focus on reconstruction", "Fine-tuned on reconstruction", "Focus on labelling"]

_tasks = [x_lab] + y_labs
_tasks_text = [x_lab_text] + y_labs_text

# %%
feat_embs = {}
_fnames = []
for _task in _tasks:
    _fname = _tmp_dataset.ident.filter((pl.col("task") == _task) & (pl.col("seed_num") == _seed) & (pl.col("split") == _split))["fname"].item()
    _fnames.append(_fname)
    feat_embs[_task] = _tmp_dataset.metrics_dict["prediction"][_fname]["node_recon"]

# %%
print(feat_embs.keys())

# %%
print(feat_embs["multitask"].shape)

# %%
import pacmap

embedding = pacmap.PaCMAP(n_components=2, n_neighbors=None, MN_ratio=0.3, FP_ratio=4.0)

# # fit the data (The index of transformed data corresponds to the index of the original data)
# X_transformed = embedding.fit_transform(X, init="pca")

feat_embs_pacmap = {}
samples = [0, 1, 2, 3]
for _s in samples:
    feat_embs_pacmap[_s] = {}
    for _task in feat_embs.keys():
        feat_embs_pacmap[_s][_task] = embedding.fit_transform(feat_embs[_task][_s], init="pca")
        print(f"Sample {_s} Task {_task}: {feat_embs_pacmap[_s][_task].shape}")

# %% [markdown]
# #### Plot 4 samples feature emb

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.figure_dpi = 300

# %%
try:
    plt.clf()
except:
    pass

# A4纸的宽度约为21厘米（8.27英寸），高度可以根据需要调整
# a4_width_cm = 21
# cm_to_inches = 0.393701
# a4_width_inches = a4_width_cm * cm_to_inches
n_cols = len(feat_embs_pacmap)  # Samples
n_rows = len(feat_embs_pacmap[0])  # Tasks

fig_width = 2.6 * n_cols  # 调整图表的整体宽度以适应列数
fig_height = 2.4 * n_rows  # 调整图表的整体高度以适应行数

sns.set_theme(style="ticks")
sns.set_context("paper", font_scale=1.0)  # 设置图表的上下文和字体大小

fig, axes = plt.subplots(
    n_rows,
    n_cols,
    figsize=(fig_width, fig_height),
    sharex=False,  # 不共享 x 轴
    sharey=False,  # 不共享 y 轴
)
if n_rows == 1:
    axes = axes.reshape(1, -1)

for _s in samples:
    for i, _task in enumerate(y_labs):
        ax = axes[_s, i]
        if i == 0:
            ax.set_ylabel(f"Data point {_s + 1}")
        if _s == 0:
            ax.set_title(y_labs_text[i])
        sns.scatterplot(x=feat_embs_pacmap[_s][_task][:, 0], y=feat_embs_pacmap[_s][_task][:, 1], alpha=0.5, hue=_modality, s=4, ax=ax, legend=False)
        # 删除框线
        for spine in ax.spines.values():
            spine.set_visible(False)
        # 删除刻度棒和刻度数字
        ax.tick_params(axis="both", which="both", length=0)  # 隐藏刻度棒
        ax.set_xticks([])  # 清空 x 轴刻度
        ax.set_yticks([])  # 清空 y 轴刻度

fig.tight_layout(pad=1.2)
fig.show()

# Save as PNG and PDF
fig.savefig(f".fig/{fig_name}.png", dpi=300)
fig.savefig(f".fig/{fig_name}.pdf")
