# %%
import polars as pl

# %%
path_s42_tst = "/mnt/hdd2/homext/wuch/xn2p/data/raw_df/scMultiome/Ath_scMultiome_WT_split_strata/split_42_2.parquet"
path_s42_tst_eighth = "/mnt/hdd2/homext/wuch/xn2p/data/raw_df/scMultiome/Ath_scMultiome_WT_split_eighth/split_42_9.parquet"

# %%
df_n = pl.read_parquet(path_s42_tst)
df_e = pl.read_parquet(path_s42_tst_eighth)

# %%
print(df_n.__len__())
print(df_e.__len__())
# Out:
# 564
# 556

# %%
# Check intersection of obs_names
obs_names_n = set(df_n['obs_names'])
obs_names_e = set(df_e['obs_names'])

intersection = obs_names_n.intersection(obs_names_e)
print(f"Number of intersecting obs_names: {len(intersection)}")
# Out:
# Number of intersecting obs_names: 534
