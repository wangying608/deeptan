# %% [markdown]
# # Read GSE155304

# %%
import scanpy as sc

# %%
path_h5ad = "/mnt/hdd2/homext/wy/grn/GSE155304/merged.h5ad"
adata = sc.read_h5ad(path_h5ad)
print(adata)
print(adata.obs)
print(adata.var)
# Out:
# AnnData object with n_obs × n_vars = 10758 × 34218
# Empty DataFrame
# Columns: []
# ...

# %%
path_h5ad = "/mnt/hdd2/homext/wy/grn/GSE155304/annotated.h5ad"
adata = sc.read_h5ad(path_h5ad)
print(adata)
print(adata.obs)
print(adata.var)
# Out:
# AnnData object with n_obs × n_vars = 10089 × 34218
#     obs: 'Orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Percent.mt', 'Seurat_clusters', 'Celltype', 'Dataset', 'Tissue', 'Organ', 'Condition', 'Genotype', 'Libraries', 'ACE'
#     obsm: 'X_umap'
#                                  Orig.ident  nCount_RNA  nFeature_RNA  \
# SRX8840341@@_CTACGGGGTGTCTTCC-1  SRX8840341       942.0           778
# SRX8840341@@_AATCACGCACCTGCTT-1  SRX8840341      1711.0          1132
# SRX8840341@@_GCATTAGTCTGACGCG-1  SRX8840341      2925.0          1822
# SRX8840341@@_AATGAAGAGGTTGAGC-1  SRX8840341      2318.0          1490
# SRX8840340@@_CATCAGAAGGAATCGC-1  SRX8840340       618.0           464
# ...                                     ...         ...           ...
# SRX8840339@@_GCGGATCGTAAGTAGT-1  SRX8840339       567.0           392
# SRX8840341@@_AGACCATAGGCCACTC-1  SRX8840341      2377.0          1868
# SRX8840337@@_CGATGGCCACCAGGTC-1  SRX8840337       851.0           633
# ...
